# %%
import pandas as pd

file_path = 'C:/Users/darks/Documents/Netflix_project.csv'
df = pd.read_csv(file_path)

print("First few rows of the dataset:")
print(df.head())

print("\nSummary information of the dataset:")
df.info()

print("\nDescriptive statistics of the dataset:")
print(df.describe())
# Out:
# First few rows of the dataset:
#          Country  Date Added       Director   Duration  \
# 0  United States  2019-08-23      Not Given  3 Seasons
# 1      Australia  2019-11-20  Anne Fontaine    111 min
# 2    New Zealand  2019-05-12      Hepi Mita     88 min
# 3      Australia  2019-04-26    Wayne Blair     99 min
# 4  United States  2017-12-31    Stan Lathan   1 Season
#
#                                           Listed In Rating  Release Year  \
# 0                        Crime TV Shows, Docuseries  TV-MA          2019
# 1  Dramas, Independent Movies, International Movies      R          2013
# 2                                     Documentaries  TV-14          2018
# 3              Comedies, Dramas, Independent Movies  PG-13          2012
# 4         Stand-Up Comedy & Talk Shows, TV Comedies  TV-MA          2017
#
#   Show Id                                             Title     Type   Budget  \
# 0   s3562                13 Reasons Why: Beyond the Reasons  TV Show  5941419
# ...

# %%
missing_values = df.isnull().sum()

missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Dataset, is already cleaned

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['Profit'] = df['Sales'] - df['Budget']
country_profit = df.groupby('Country')['Profit'].sum().sort_values()

plt.figure(figsize=(14, 7))
country_profit.plot(kind='bar', color='skyblue')
plt.title('Total Profit by Country')
plt.xlabel('Country')
plt.ylabel('Total Profit')
plt.show()

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(x='Type', y='Sales', data=df)
plt.title('Sales Distribution by Type')
plt.show()

plt.figure(figsize=(14, 7))
sns.boxplot(x='Country', y='Sales', data=df)
plt.xticks(rotation=90)
plt.title('Sales Distribution by Country')
plt.show()

# %%
plt.figure(figsize=(14, 7))
sns.scatterplot(x='Sales', y='Profit', data=df)
plt.title('Sales vs. Profit')
plt.show()

# %%
top_customers_sales = df.groupby('Title')['Sales'].sum().sort_values(ascending=False).head(10)
top_customers_profit = df.groupby('Title')['Profit'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(14, 7))
top_customers_sales.plot(kind='bar', color='skyblue')
plt.title('Top 10 Titles by Sales')
plt.show()

plt.figure(figsize=(14, 7))
top_customers_profit.plot(kind='bar', color='skyblue')
plt.title('Top 10 Titles by Profit')
plt.show()

# %% [markdown]
# We do have city coloumn, but we dont have continent coulmn which we need it for more Data Analytics

# %%
unique_countries = df['Country'].unique()
print(unique_countries)
# Out:
# ['United States' 'Australia' 'New Zealand' 'Pakistan' 'India'
#  'United Kingdom' 'Turkey' 'Colombia' 'Indonesia' 'Spain' 'Not Given'
#  'Taiwan' 'South Korea' 'Ireland' 'Lebanon' 'Vietnam' 'Japan' 'Thailand'
#  'Poland' 'Egypt' 'France' 'Nigeria' 'Hong Kong' 'Germany' 'Austria'
#  'Canada' 'Peru' 'Mexico' 'Italy' 'Singapore' 'South Africa' 'China'
#  'Georgia' 'Philippines' 'Switzerland' 'United Arab Emirates' 'Luxembourg'
#  'Uruguay' 'Czech Republic' 'Romania' 'Brazil' 'Saudi Arabia' 'Argentina'
#  'Chile' 'Kuwait' 'Norway' 'Malaysia' 'Netherlands' 'Israel' 'Belgium'
#  'Sweden' 'Senegal' 'Denmark' 'Finland' 'Russia' 'Croatia' 'Cambodia'
#  'Bulgaria' 'Bangladesh' 'Ghana' 'Syria' 'Ukraine' 'Portugal'
#  'Puerto Rico' 'Jamaica' 'Iceland' 'Kenya' 'Hungary' 'Serbia' 'Jordan'
#  'Soviet Union' 'Guatemala' 'Somalia' 'Zimbabwe' 'Belarus' 'Slovenia'
#  'Iran' 'West Germany' 'Venezuela' 'Greece' 'Cameroon' 'Namibia'
#  'Paraguay' 'Mozambique' 'Mauritius' 'Cyprus']

# %% [markdown]
# Now, we have unique names of city, it is time to put them in their cotinent

# %%
country_to_continent = {
    'United States': 'North America',
    'Australia': 'Oceania',
    'New Zealand': 'Oceania',
    'Pakistan': 'Asia',
    'India': 'Asia',
    'United Kingdom': 'Europe',
    'Turkey': 'Asia',
    'Colombia': 'South America',
    'Indonesia': 'Asia',
    'Spain': 'Europe',
    'Not Given': 'Unknown',
    'Taiwan': 'Asia',
    'South Korea': 'Asia',
    'Ireland': 'Europe',
    'Lebanon': 'Asia',
    'Vietnam': 'Asia',
    'Japan': 'Asia',
    'Thailand': 'Asia',
    'Poland': 'Europe',
    'Egypt': 'Africa',
    'France': 'Europe',
    'Nigeria': 'Africa',
    'Hong Kong': 'Asia',
    'Germany': 'Europe',
    'Austria': 'Europe',
    'Canada': 'North America',
    'Peru': 'South America',
    'Mexico': 'North America',
    'Italy': 'Europe',
    'Singapore': 'Asia',
    'South Africa': 'Africa',
    'China': 'Asia',
    'Georgia': 'Asia',
    'Philippines': 'Asia',
    'Switzerland': 'Europe',
    'United Arab Emirates': 'Asia',
    'Luxembourg': 'Europe',
    'Uruguay': 'South America',
    'Czech Republic': 'Europe',
    'Romania': 'Europe',
    'Brazil': 'South America',
    'Saudi Arabia': 'Asia',
    'Argentina': 'South America',
    'Chile': 'South America',
    'Kuwait': 'Asia',
    'Norway': 'Europe',
    'Malaysia': 'Asia',
    'Netherlands': 'Europe',
    'Israel': 'Asia',
    'Belgium': 'Europe',
    'Sweden': 'Europe',
    'Senegal': 'Africa',
    'Denmark': 'Europe',
    'Finland': 'Europe',
    'Russia': 'Europe',
    'Croatia': 'Europe',
    'Cambodia': 'Asia',
    'Bulgaria': 'Europe',
    'Bangladesh': 'Asia',
    'Ghana': 'Africa',
    'Syria': 'Asia',
    'Ukraine': 'Europe',
    'Portugal': 'Europe',
    'Puerto Rico': 'North America',
    'Jamaica': 'North America',
    'Iceland': 'Europe',
    'Kenya': 'Africa',
    'Hungary': 'Europe',
    'Serbia': 'Europe',
    'Jordan': 'Asia',
    'Soviet Union': 'Europe',
    'Guatemala': 'North America',
    'Somalia': 'Africa',
    'Zimbabwe': 'Africa',
    'Belarus': 'Europe',
    'Slovenia': 'Europe',
    'Iran': 'Asia',
    'West Germany': 'Europe',
    'Venezuela': 'South America',
    'Greece': 'Europe',
    'Cameroon': 'Africa',
    'Namibia': 'Africa',
    'Paraguay': 'South America',
    'Mozambique': 'Africa',
    'Mauritius': 'Africa',
    'Cyprus': 'Europe'
}

df['Continent'] = df['Country'].map(country_to_continent)

print(df.head())

df['Profit'] = df['Sales'] - df['Budget']
continent_profit = df.groupby('Continent')['Profit'].sum().sort_values()

plt.figure(figsize=(14, 7))
continent_profit.plot(kind='bar', color='skyblue')
plt.title('Total Profit by Continent')
plt.xlabel('Continent')
plt.ylabel('Total Profit')
plt.show()
# Out:
#          Country  Date Added       Director   Duration  \
# 0  United States  2019-08-23      Not Given  3 Seasons
# 1      Australia  2019-11-20  Anne Fontaine    111 min
# 2    New Zealand  2019-05-12      Hepi Mita     88 min
# 3      Australia  2019-04-26    Wayne Blair     99 min
# 4  United States  2017-12-31    Stan Lathan   1 Season
#
#                                           Listed In Rating  Release Year  \
# 0                        Crime TV Shows, Docuseries  TV-MA          2019
# 1  Dramas, Independent Movies, International Movies      R          2013
# 2                                     Documentaries  TV-14          2018
# 3              Comedies, Dramas, Independent Movies  PG-13          2012
# 4         Stand-Up Comedy & Talk Shows, TV Comedies  TV-MA          2017
#
#   Show Id                                             Title     Type   Budget  \
# 0   s3562                13 Reasons Why: Beyond the Reasons  TV Show  5941419
# ...

# %%
missing_values = df.isnull().sum()

missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %%
df['Date Added'] = pd.to_datetime(df['Date Added'])

df.set_index('Date Added', inplace=True)

monthly_sales = df['Sales'].resample('M').sum()

plt.figure(figsize=(14, 7))
monthly_sales.plot()
plt.title('Monthly Sales Over Time')
plt.show()

# %% [markdown]
# Let's have another coloumn by name of 'Profitable?'
# It's a calculation between sales and budget

# %%
import numpy as np
df['Profitable?'] = df['Sales'] - df['Budget']
df['Profitable?'] = np.where(df['Profit'] > 0, 'Yes', 'No')
print(df.head())
# Out:
#                   Country       Director   Duration  \
# Date Added
# 2019-08-23  United States      Not Given  3 Seasons
# 2019-11-20      Australia  Anne Fontaine    111 min
# 2019-05-12    New Zealand      Hepi Mita     88 min
# 2019-04-26      Australia    Wayne Blair     99 min
# 2017-12-31  United States    Stan Lathan   1 Season
#
#                                                    Listed In Rating  \
# Date Added
# 2019-08-23                        Crime TV Shows, Docuseries  TV-MA
# 2019-11-20  Dramas, Independent Movies, International Movies      R
# 2019-05-12                                     Documentaries  TV-14
# 2019-04-26              Comedies, Dramas, Independent Movies  PG-13
# 2017-12-31         Stand-Up Comedy & Talk Shows, TV Comedies  TV-MA
#
#             Release Year Show Id  \
# Date Added
# 2019-08-23          2019   s3562
# 2019-11-20          2013   s6092
# 2019-05-12          2018   s3831
# 2019-04-26          2012   s8498
# ...

# %%
df.reset_index(inplace=True)

# %%
file_path = 'C:/Users/darks/Documents/Cleaned_Netflix_project.csv'
df.to_csv(file_path, index=False)
print(f"Dataset saved successfully as '{file_path}'")
# Out:
# Dataset saved successfully as 'C:/Users/darks/Documents/Cleaned_Netflix_project.csv'

# %%
file_path = 'C:/Users/darks/Documents/Cleaned_Netflix_project.csv'
df = pd.read_csv(file_path)

print("First few rows of the dataset:")
print(df.head())

print("\nSummary information of the dataset:")
df.info()

print("\nDescriptive statistics of the dataset:")
print(df.describe())

df.rename(columns={
    'Date Added': 'Date_Added',
    'Listed In': 'Listed_In',
    'Release Year': 'Release_Year',
    'Show Id': 'Show_Id'
}, inplace=True)
# Out:
# First few rows of the dataset:
#    index  Date Added        Country       Director   Duration  \
# 0      0  2019-08-23  United States      Not Given  3 Seasons
# 1      1  2019-11-20      Australia  Anne Fontaine    111 min
# 2      2  2019-05-12    New Zealand      Hepi Mita     88 min
# 3      3  2019-04-26      Australia    Wayne Blair     99 min
# 4      4  2017-12-31  United States    Stan Lathan   1 Season
#
#                                           Listed In Rating  Release Year  \
# 0                        Crime TV Shows, Docuseries  TV-MA          2019
# 1  Dramas, Independent Movies, International Movies      R          2013
# 2                                     Documentaries  TV-14          2018
# 3              Comedies, Dramas, Independent Movies  PG-13          2012
# 4         Stand-Up Comedy & Talk Shows, TV Comedies  TV-MA          2017
#
#   Show Id                                             Title     Type   Budget  \
# ...

# %%
file_path = 'C:/Users/darks/Documents/Cleaned_Netflix_project.csv'
df.to_csv(file_path, index=False)
print(f"Dataset saved successfully as '{file_path}'")
# Out:
# Dataset saved successfully as 'C:/Users/darks/Documents/Cleaned_Netflix_project.csv'

# %%
print(df.head())
# Out:
#    index  Date_Added        Country       Director   Duration  \
# 0      0  2019-08-23  United States      Not Given  3 Seasons
# 1      1  2019-11-20      Australia  Anne Fontaine    111 min
# 2      2  2019-05-12    New Zealand      Hepi Mita     88 min
# 3      3  2019-04-26      Australia    Wayne Blair     99 min
# 4      4  2017-12-31  United States    Stan Lathan   1 Season
#
#                                           Listed_In Rating  Release_Year  \
# 0                        Crime TV Shows, Docuseries  TV-MA          2019
# 1  Dramas, Independent Movies, International Movies      R          2013
# 2                                     Documentaries  TV-14          2018
# 3              Comedies, Dramas, Independent Movies  PG-13          2012
# 4         Stand-Up Comedy & Talk Shows, TV Comedies  TV-MA          2017
#
#   Show_Id                                             Title     Type   Budget  \
# ...

# %% [markdown]
# Let's check the format of Date_Added coloumn

# %%
print("Data type of 'Date_Added':", df['Date_Added'].dtype)
# Out:
# Data type of 'Date_Added': object

# %% [markdown]
# We need to change the format in order to make it standard

# %%
df['Date_Added'] = pd.to_datetime(df['Date_Added'], errors='coerce')

# %%
print("Data type of 'Date_Added':", df['Date_Added'].dtype)
# Out:
# Data type of 'Date_Added': datetime64[ns]

# %% [markdown]
# We do have a coloumn which is Show_id, the numbers in this coloumn don't have proper type of order and also the numbers are confusing, so we want to drop this coloumn but add another the coloumn by name Show_ID, although the order of the new column will be according to the old column.

# %%
file_path = 'C:/Users/darks/Documents/Cleaned_Netflix_project.csv'
df = pd.read_csv(file_path)
df_sorted = df.sort_values(by='Show_Id')


df_sorted.drop(columns=['Show_Id'], inplace=True)

# Add a new column Show_ID with sequential IDs starting from 1000
df_sorted['Show_ID'] = range(1000, 1000 + len(df_sorted))


print(df_sorted)
df_sorted.to_csv('C:/Users/darks/Documents/Cleaned_Netflix_project.csv', index=False)
file_path = 'C:/Users/darks/Documents/Cleaned_Netflix_project.csv'
df = pd.read_csv(file_path)
# Out:
#       index  Date_Added         Country                          Director  \
# 1889   1889  2021-09-25   United States                   Kirsten Johnson
# 5353   5353  2021-09-24   United States                    Theodore Melfi
# 714     714  2021-09-07          France                         Not Given
# 2943   2943  2021-04-22         Germany                         Joe Penna
# 1143   1143  2021-04-22           India                   Ahishor Solomon
# ...     ...         ...             ...                               ...
# 6989   6989  2021-04-23         Nigeria                      Kayode Kasum
# 8732   8732  2021-04-23          Turkey  Yılmaz Erdoğan, Ömer Faruk Sorak
# 1822   1822  2021-04-22           Japan                   Takashi Shimizu
# 1189   1189  2021-04-22  United Kingdom               Alastair Fothergill
# 2578   2578  2021-04-22           India                         Not Given
#
#       Duration                                          Listed_In Rating  \
# ...

# %%
print(df.head())
# Out:
#    index  Date_Added        Country         Director  Duration  \
# 0   1889  2021-09-25  United States  Kirsten Johnson    90 min
# 1   5353  2021-09-24  United States   Theodore Melfi   104 min
# 2    714  2021-09-07         France        Not Given  1 Season
# 3   2943  2021-04-22        Germany        Joe Penna   116 min
# 4   1143  2021-04-22          India  Ahishor Solomon   126 min
#
#                                   Listed_In Rating  Release_Year  \
# 0                             Documentaries  PG-13          2020
# 1                          Comedies, Dramas  PG-13          2021
# 2                    TV Comedies, TV Dramas  TV-MA          2021
# 3   Dramas, International Movies, Thrillers  TV-MA          2021
# 4  Action & Adventure, International Movies  TV-MA          2020
#
#                   Title     Type   Budget    Sales   Profit      Continent  \
# 0  Dick Johnson Is Dead    Movie  4123396  6476362  2352966  North America
# ...

# %%
from sqlalchemy import create_engine


# My database connection details
user = 'root'
password = 'Ali1375'
host = 'localhost'
port = 3306
database = 'netflix_project'  # my database name here

file_path = 'C:/Users/darks/Documents/Cleaned_Netflix_project.csv'

# Table name which I want for MySQL 
table_name = 'netflix_project'

# Creating the connection engine
try:
    db = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}')
    print("Connection to MySQL DB successful")
except Exception as e:
    print(f"Error connecting to MySQL DB: {e}")

# Importing the CSV file into the MySQL table
try:
    df = pd.read_csv(file_path)
    df.to_sql(table_name, con=db, if_exists='replace', index=False)
    print(f'{file_path} has been imported into the table {table_name}')
except FileNotFoundError:
    print(f'File {file_path} not found.')
except Exception as e:
    print(f'Error importing {file_path} into MySQL DB: {e}')
finally:
    if 'db' in locals():
        db.dispose()  # At the end I want to close the database connection
# Out:
# Connection to MySQL DB successful
# C:/Users/darks/Documents/Cleaned_Netflix_project.csv has been imported into the table netflix_project

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         8790 non-null   int64
#  1   Date_Added    8790 non-null   object
#  2   Country       8790 non-null   object
#  3   Director      8790 non-null   object
#  4   Duration      8790 non-null   object
#  5   Listed_In     8790 non-null   object
#  6   Rating        8790 non-null   object
#  7   Release_Year  8790 non-null   int64
#  8   Title         8790 non-null   object
#  9   Type          8790 non-null   object
#  10  Budget        8790 non-null   int64
#  11  Sales         8790 non-null   int64
#  12  Profit        8790 non-null   int64
#  13  Continent     8790 non-null   object
#  14  Profitable?   8790 non-null   object
#  15  Show_ID       8790 non-null   int64
# dtypes: int64(6), object(10)
# memory usage: 1.1+ MB

# %%
# Create DataFrame for shows table
shows = df[['Show_ID', 'Date_Added', 'Country', 'Director', 'Duration', 'Listed_In', 'Rating', 'Release_Year', 'Title', 'Type', 'Continent', 'Profitable?']]

# Create DataFrame for financials table
financials = df[['Show_ID', 'Budget', 'Sales', 'Profit']]


print("Shows Table:")
print(shows.head())

print("\nFinancials Table:")
print(financials.head())
# Out:
# Shows Table:
#    Show_ID  Date_Added        Country         Director  Duration  \
# 0     1000  2021-09-25  United States  Kirsten Johnson    90 min
# 1     1001  2021-09-24  United States   Theodore Melfi   104 min
# 2     1002  2021-09-07         France        Not Given  1 Season
# 3     1003  2021-04-22        Germany        Joe Penna   116 min
# 4     1004  2021-04-22          India  Ahishor Solomon   126 min
#
#                                   Listed_In Rating  Release_Year  \
# 0                             Documentaries  PG-13          2020
# 1                          Comedies, Dramas  PG-13          2021
# 2                    TV Comedies, TV Dramas  TV-MA          2021
# 3   Dramas, International Movies, Thrillers  TV-MA          2021
# 4  Action & Adventure, International Movies  TV-MA          2020
#
#                   Title     Type      Continent Profitable?
# 0  Dick Johnson Is Dead    Movie  North America         Yes
# ...

# %%
user = 'root'
password = 'Ali1375'
host = 'localhost'
port = 3306
database = 'netflix_project' 


shows_table = 'shows'
financials_table = 'financials'

try:
    db = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}')
    print("Connection to MySQL DB successful")
except Exception as e:
    print(f"Error connecting to MySQL DB: {e}")

try:
    shows_df = df[['Show_ID', 'Date_Added', 'Country', 'Director', 'Duration', 'Listed_In', 'Rating', 'Release_Year', 'Title', 'Type', 'Continent']]
    shows_df.to_sql(name=shows_table, con=db, if_exists='replace', index=False)
    print(f'Shows information has been saved to MySQL table {shows_table}')
except Exception as e:
    print(f'Error saving shows information to MySQL: {e}')


try:
    financials_df = df[['Show_ID', 'Budget', 'Sales', 'Profit','Profitable?']]
    financials_df.to_sql(name=financials_table, con=db, if_exists='replace', index=False)
    print(f'Financials information has been saved to MySQL table {financials_table}')
except Exception as e:
    print(f'Error saving financials information to MySQL: {e}')

finally:
    if 'db' in locals():
        db.dispose()
# Out:
# Connection to MySQL DB successful
# Shows information has been saved to MySQL table shows
# Financials information has been saved to MySQL table financials

# %% [markdown]
# Performing A/B TESTING:

# %%
from scipy import stats
import pandas as pd

# Merge the two DataFrames on Show_ID
merged_df = pd.merge(shows, financials, on='Show_ID')

# Assume we are testing the effect of 'Type' on 'Profit'
group_a = merged_df[merged_df['Type'] == 'Movie']['Profit']
group_b = merged_df[merged_df['Type'] == 'TV Show']['Profit']

# Perform an independent t-test
t_stat, p_val = stats.ttest_ind(group_a, group_b, nan_policy='omit')

t_stat, p_val
# Out:
# (41.50793190966893, 0.0)

# %% [markdown]
# KNN and Decision Tree TESTING

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# For KNN and Decision Tree, we need to prepare the data
# Let's classify 'Profitable?' based on other features

# Encode categorical variables
merged_df['Profitable'] = merged_df['Profitable?'].apply(lambda x: 1 if x == 'Yes' else 0)
features = ['Budget', 'Sales', 'Release_Year']
X = merged_df[features]
y = merged_df['Profitable']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# KNN Classifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)
knn_accuracy = accuracy_score(y_test, y_pred_knn)

# Decision Tree Classifier
tree = DecisionTreeClassifier(random_state=42)
tree.fit(X_train, y_train)
y_pred_tree = tree.predict(X_test)
tree_accuracy = accuracy_score(y_test, y_pred_tree)

knn_accuracy, tree_accuracy
# Out:
# (0.9935532802427001, 0.9908987485779295)

# %% [markdown]
# ANOVA TESTING to see if there's a significant difference in 'Budget' across different 'Continent'

# %%
anova_result = stats.f_oneway(
    merged_df[merged_df['Continent'] == 'North America']['Budget'],
    merged_df[merged_df['Continent'] == 'Europe']['Budget'],
    merged_df[merged_df['Continent'] == 'Asia']['Budget'],
    # Add other continents as needed
)

anova_result.statistic, anova_result.pvalue
# Out:
# (2.4664390238194427, 0.08495249012157291)
